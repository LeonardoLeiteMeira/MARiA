# %% [markdown]
# # Lendo e manipulando as bases de dados lidas no notion

# %%
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from database import BaseDatabase
from repository import UserRepository, NotionDatasourceRepository
from domain import UserDomain

database = BaseDatabase()
notion_db_repo = NotionDatasourceRepository(database)
user_repository = UserRepository(database)
user_domain = UserDomain(user_repository, notion_db_repo)

# %%
user = await user_domain.get_user_by_phone_number("5531933057272")
# Out:
# 2025-06-27 09:39:09,107 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2025-06-27 09:39:09,108 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-06-27 09:39:09,111 INFO sqlalchemy.engine.Engine select current_schema()
# 2025-06-27 09:39:09,111 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-06-27 09:39:09,114 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2025-06-27 09:39:09,114 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-06-27 09:39:09,116 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# ...

# %%
dbs = await user_domain.get_user_notion_datasources_taged(user.id)
dbs
# Out:
# 2025-06-27 09:40:49,470 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-06-27 09:40:49,476 INFO sqlalchemy.engine.Engine SELECT notion_databases.id, notion_databases.user_id, notion_databases.table_name, notion_databases.table_id, notion_databases.tag, notion_databases.created_at, notion_databases.updated_at
# FROM notion_databases
# WHERE notion_databases.user_id = $1::UUID AND notion_databases.tag IS NOT NULL
# 2025-06-27 09:40:49,479 INFO sqlalchemy.engine.Engine [generated in 0.00351s] (UUID('64a61a98-a92c-4cf1-b258-a50bde8cef3b'),)
# 2025-06-27 09:40:49,505 INFO sqlalchemy.engine.Engine ROLLBACK
# [Gestões - months - 1cb14f69-1c83-8185-8f6d-d41c0feb3ab8 ,
#  Planejamento financeiro Gestão - planning - 1cb14f69-1c83-819d-b7ab-e1dad9990d87 ,
#  Transações - transactions - 1cb14f69-1c83-81d9-a75f-fb3e58f0a481 ,
#  Macro Categorias - types - 1f514f69-1c83-8054-a52a-cfa5dc34fdd1 ,
#  Contas/Cartões - cards - 1cb14f69-1c83-81e1-bf00-e7b91896c0ef ,
# ...

# %%
dbs[0].tag
# Out:
# Gestões - months - 1cb14f69-1c83-8185-8f6d-d41c0feb3ab8
